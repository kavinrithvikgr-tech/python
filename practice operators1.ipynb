# %%
a=15
b=10

# %%
print(a>5 or a<5)
# Out:
# True

# %%
print(a<5 and a>5)
# Out:
# False

# %%
a="apple"
b="apple"
c = a
print(c is b)
# Out:
# True

# %%
print(a is not b)
# Out:
# False

# %%
a=input("enter the number")
b=input("enter the number")
print(a is not b)
# Out:
# enter the number 5
# enter the number 6
# True

# %%
a="hey i am kavin"
print("hello" in a)
# Out:
# False

# %%
a="hello i am kavin"
print("hello" not in a)
# Out:
# False

# %%
a=1,2,3,4
2 in a
# Out:
# True
