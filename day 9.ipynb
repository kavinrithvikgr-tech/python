# %%
thistuple=("apple", "banana", "cherry")
print(len(thistuple))
# Out:
# 3

# %%
thistuple = tuple(("apple", "banana", "cherry"))
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
s1={"hi","hello",5,6,7,8}
s2={2,3,4,5}
s1.remove("hello")
s1.add("apple")
s1
s1=s1.union(s2)
s1
# Out:
# {2, 3, 4, 5, 6, 7, 8, 'apple', 'hi'}

# %%
s1
# Out:
# {2, 3, 4, 5, 6, 7, 8, 'apple', 'hi'}
