# %%
name=str(input("enter your name"))
lan=str(input("enter known computer language"))
exp=str(input("enter your years of expirence"))
loc=str(input("enter your location"))

if lan=="python" and exp=="1" and loc=="chennai":
    print("you are selected for infosys")

elif lan=="python" and exp=="fresher" and loc=="coimbatore":
    print("you are selected for wipro")

elif lan=="java" and exp=="fresher" and loc=="chennai":
    print("you are selected for TCS")

elif lan=="java" and exp=="1" and loc=="bangalore":
    print("you are selected for cognizant")

else:
    print("sorry, you are disqualified")
# Out:
# enter your name a
# enter known computer language b
# enter your years of expirence d
# enter your location d
# sorry, you are disqualified

# %%
name=str(input("enter your name"))
lan=str(input("enter known computer language"))
exp=str(input("enter your years of expirence"))
loc=str(input("enter your location"))

if lan=="python" and exp=="1" and loc=="chennai":
    out=f"{name}, you are selected for infosys
    print(out)
# Out:
#   Cell In[21], line 7
#     out=f"{name}, you are selected for infosys
#         ^
# SyntaxError: unterminated f-string literal (detected at line 7)
