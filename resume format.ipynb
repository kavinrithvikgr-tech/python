# %%
name=str(input("enter your name"))
lan=str(input("enter known computer language"))
exp=int(input("enter your years of expirence"))
loc=str(input("enter your location"))

if lan=="python" and exp>=1 and loc=="chennai":
    print("you are selected for infosys")

elif lan=="python" and exp>=0 and loc=="coimbatore":
    print("you are selected for wipro")

elif lan=="java" and exp>=0 and loc=="chennai":
    print("you are selected for TCS")

elif lan=="java" and exp>=1 and loc=="bangalore":
    print("you are selected for cognizant")

else:
    print("sorry, you are not eligible")
# Out:
# enter your name kavin
# enter known computer language python
# enter your years of expirence 2
# enter your location chennai
# you are selected for infosys

# %%
name=str(input("enter your name"))
lan=str(input("enter known computer language"))
exp=int(input("enter your years of expirence"))
loc=str(input("enter your location"))

if lan=="python" and exp>=1 and loc=="chennai":
    out=f"{name}, you are eligible for infosys"
    print(out)
# Out:
# enter your name kavin
# enter known computer language python
# enter your years of expirence 1
# enter your location chennai
# kavin, you are eligible for infosys
