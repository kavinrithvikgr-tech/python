# %% [raw]
# print("kavin")

# %%
print("kavin")
# Out:
# kavin

# %%
print(2)
# Out:
# 2

# %%
a=2
b=3
c=4
c
# Out:
# 4

# %%
print(a)
# Out:
# 2

# %%
a=5
b=10
a+b
# Out:
# 15

# %%
a=b=c=10
c
# Out:
# 10

# %%
a,b,c=1,2,3
c
# Out:
# 3

# %%
a,b,c=("apple","orange","banana")
c
# Out:
# 'banana'

# %%
k=input()
print(k)
# Out:
#  apple
# apple

# %%
k=input("blank space")
k
# Out:
# blank space hello
# 'hello'

# %%
name=input("enter your name")
name
# Out:
# enter your name kavin
# 'kavin'

# %%
a="abcd"
print(type(a))
# Out:
# <class 'str'>

# %%
a=123
print(type(a))
# Out:
# <class 'int'>

# %%
a=10.5
print(type(a))
# Out:
# <class 'float'>

# %%
a=10j+5
print(type(a))
# Out:
# <class 'complex'>

# %%
a=float(5)
a
# Out:
# 5.0

# %%
a=complex(5)
a
# Out:
# (5+0j)

# %%
a=str(5)
a
# Out:
# '5'

# %%
a=int(5)
a
# Out:
# 5

# %%
k=10+15j
k.imag
# Out:
# 15.0

# %%
k.real
# Out:
# 10.0

# %%
k=10
k1=int(k)
k2=str(k)
k3=complex(k)
k4=float(k)
print(k1)
print(k2)
print(k3)
print(k4)
# Out:
# 10
# 10
# (10+0j)
# 10.0

# %%
k=complex(input("enter the input"))
print(type(k))
print(k)
# Out:
# enter the input 5
# <class 'complex'>
# (5+0j)

# %%
k="hi, how are you"
print(len(k))
# Out:
# 15

# %%
print(k[4])
# Out:
# h

# %%
print(k[-2])
# Out:
# o

# %%
k="hello besant"
print(k[3:8])
# Out:
# lo be

# %%
k="hello kavin"
k.capitalize()
# Out:
# 'Hello kavin'

# %%
k="hello kavin"
k.upper()
# Out:
# 'HELLO KAVIN'

# %%
k.lower()
# Out:
# 'hello kavin'

# %%
k="   hello kavin    "
k.strip()
# Out:
# 'hello kavin'

# %%
k="hellokavin"
k.split("k")
# Out:
# ['hello', 'avin']

# %%
k="hello kavin"
k.split()
# Out:
# ['hello', 'kavin']

# %%
a=input("enter your name")
b=input("enter your age")
out=f"hi im {a}, my age is {b}"
print(out)
# Out:
# enter your name kavin
# enter your age 22
# hi im kavin, my age is 22

# %%
a="hi im ajith"
a.replace("ajith","kavin")
# Out:
# 'hi im kavin'

# %%
a="hi, im kavin"
x=a.index("k")
x
# Out:
# 7

# %%
k="hello kavin"
x=k.startswith("h")
y=k.endswith("n")
print(x)
print(y)
# Out:
# True
# True

# %%
# Out:
#   Cell In[73], line 4
#     if gender == "male":
#     ^
# IndentationError: unexpected indent
