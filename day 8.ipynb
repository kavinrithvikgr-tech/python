# %%
l=[1,"hi",1.8,"7.8",True];l
l.replace("1","3")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 l=[1,"hi",1.8,"7.8",True]
# ----> 2 l.replace("1","3")
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
l[0]="python"
l
# Out:
# ['python', 'hi', 1.8, '7.8', True]

# %%
l=["hi","2","hello",75]
l[1]=("36")
l.pop(2)
l.append("86")
print(l)
# Out:
# ['hi', '36', 75, '86']
