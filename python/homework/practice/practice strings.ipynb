# %%
k="hey i am kavin"
print(len(k))
# Out:
# 14

# %%
k="my name is kavin"
print(k[3])
# Out:
# n

# %%
print(k[-5])
# Out:
# k

# %%
print(k[:8])
# Out:
# my name

# %%
print(k[10:])
# Out:
#  kavin

# %%
print(k[2:-9])
# Out:
#  name

# %%
print(k.upper())
# Out:
# MY NAME IS KAVIN

# %%
a=(k.upper())

# %%
a
# Out:
# 'MY NAME IS KAVIN'

# %%
print(a.lower())
# Out:
# my name is kavin

# %%
print(a.capitalize())
# Out:
# My name is kavin

# %%
b="hey, how are you doing"
b.capitalize()
# Out:
# 'Hey, how are you doing'

# %%
a="   hey,world    "
a.strip()
# Out:
# 'hey,world'

# %%
a="    hey,   world   "

# %%
a.strip()
# Out:
# 'hey,   world'

# %%
a="    hey,kavin    "
b=a.strip()
print(len(b))
print(len(a))
print(b)
print(a)
# Out:
# 9
# 17
# hey,kavin
#     hey,kavin

# %%
print(a[1:5])
# Out:
#    h

# %%
a="i am doing fine"
print(a.split())
print(a.split("d"))
# Out:
# ['i', 'am', 'doing', 'fine']
# ['i am ', 'oing fine']

# %%
a=input("enter your name")
b=input("enter your fathers name")


out=f"i am {a}, my fathers name is {b}"
print(out)
# Out:
# enter your name a
# enter your fathers name b
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 6
#       2 b=input("enter your fathers name")
#       5 out=f"i am {a}, my fathers name is {b}"
# ----> 6 print(out)
#
# TypeError: 'str' object is not callable

# %%
name=input("enter your name")
place=input("enter your place")

k=f"i am {name}, from {place}"
k
# Out:
# enter your name kavin
# enter your place madurai
# 'i am kavin, from madurai'
