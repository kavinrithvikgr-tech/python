# %%
k="my name is kavin"
print(k.replace("kavin", "danush"))
# Out:
# my name is danush

# %%
k="i am a boy"
a=k.replace("boy", "girl")
print(a)
# Out:
# i am a girl

# %%
a="Hey I AM Kavin"
b=a.casefold()
b
# Out:
# 'hey i am kavin'

# %%
a="Hey I AM Kavin"
b=a.lower()
b
# Out:
# 'hey i am kavin'

# %%
a="my name is kavin"
b=a.center(10)
print(len(a))
print(len(b))
print(b)
# Out:
# 16
# 16
# my name is kavin

# %%
a="my name is kavin"
b=a.count("kavin")

# %%
a="hey, i am kavin"
x=a.capitalize()
x
# Out:
# 'Hey, i am kavin'

# %%
a="hey, i am kavin"
x=a.title()
x
# Out:
# 'Hey, I Am Kavin'
