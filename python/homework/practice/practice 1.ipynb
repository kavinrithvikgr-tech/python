# %%
k=10
print(type(k))
# Out:
# <class 'int'>

# %%
k=10.5
print(type(k))
# Out:
# <class 'float'>

# %%
k=5j+2
print(type(k))
# Out:
# <class 'complex'>

# %%
k="kavin"
print(type(k))
# Out:
# <class 'str'>

# %%
k=True
print(type(k))
# Out:
# <class 'bool'>

# %%
k="kavin is a boy"
l="kavin is a girl"
a=(k==l)
print(bool(a))
# Out:
# False

# %% [markdown]
# #####

# %%
a=5
b=10
k=(a+b==15)
print(bool(k))
# Out:
# True

# %%
k=10
print(bool(k))
# Out:
# True

# %%
print(complex(k))
# Out:
# (10+0j)

# %%
print(str((k)
# Out:
#   Cell In[14], line 1
#     print(str((k)
#                  ^
# _IncompleteInputError: incomplete input

# %%
print(float(k))
# Out:
# 10.0

# %%
k=10j+5
print(k.imag)
# Out:
# 10.0

# %%
print(k.real)
# Out:
# 5.0

# %%
k=15j+25
print(k.real)
# Out:
# 25.0

# %%
print(k.imag)
# Out:
# 15.0

# %%
k=10
k1=(str(k))
k2=(float(k))
k3=(complex(k))
k4=(bool(k))
print(k1)
# Out:
# 10

# %%
k2
# Out:
# 10.0

# %%
k3
# Out:
# (10+0j)

# %%
k4
# Out:
# True

# %%
k=(input("enter the number"))
a=float(k)
print(a) 
print(type(a))
# Out:
# enter the number 12
# 12.0
# <class 'float'>

# %%
a=15j+25
print(a.real)
print(a.imag)
# Out:
# 25.0
# 15.0

# %%
k=float(input("enter the number"))
print(type(k))
k
# Out:
# enter the number 12
# <class 'float'>
# 12.0

# %%
k=int(7.8)
k1=bool(k)
k2=complex(k1)
k2
# Out:
# (1+0j)

# %%
k1
# Out:
# True
