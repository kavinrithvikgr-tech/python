# %%
legal variables

# %%
number = 1
num_ber = 1
_num_ber =1
NUMBER =1
nuMbEr =1
NUMBER1 =1

print(number)
print(num_ber)
print(_num_ber)
print(NUMBER)
print(nuMbEr)
print(NUMBER1)
# Out:
# 1
# 1
# 1
# 1
# 1
# 1

# %%
Illegal variable

# %%
1number =1
num-ber =1
my var =1
@my var=1


print(1number)
print(num-ber)
print(my var)
print(@my var)
# Out:
#   Cell In[4], line 1
#     1number =1
#     ^
# SyntaxError: invalid decimal literal
