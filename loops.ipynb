# %%
l=[59,1,8,9,30,2,5]
i=0
max=l[0]
min=l[0]
while i<len(l):
    if l[i]>max:
        max=l[i]
    if l[i]<min:
        min=l[i]
    i+=1
print("maximum:",max)
print(min)
# Out:
# maximum: 59
# 1

# %%
l=[59,1,8,9,30,2,5]
for i in l:
    if i<max and i>secondmax:
        secondmax=i
    if i>min and i<secondmin:
        secondmax=i
print(secondmax, secondmin)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       3     if i<max and i>secondmax:
#       4         secondmax=i
# ----> 5     if i>min and i<secondmin:
#       6         secondmax=i
#       7 print(secondmax, secondmin)
#
# NameError: name 'secondmin' is not defined
