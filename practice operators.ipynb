# %%
a=int(input("enter the number"))
b=int(input("enter the number"))
# Out:
# enter the number 25
# enter the number 7

# %%
c=a+b
c
# Out:
# 25

# %%
c=a-b
c
# Out:
# -5

# %%
c=a/b
c
# Out:
# 0.6666666666666666

# %%
c=a*b
c
# Out:
# 150

# %%
c=a//b
c
# Out:
# 3

# %%
c=a%b
c
# Out:
# 4

# %%
c=a**b
c
# Out:
# 6103515625

# %%
print(2+3)
# Out:
# 5

# %%
print(5/2)
# Out:
# 2.5

# %%
print(5//2)
# Out:
# 2

# %%
print(5%2)
# Out:
# 1

# %%
a=5
a=a+2
a
# Out:
# 7

# %%
a+=3
a
a=10
a
# Out:
# 10

# %%
a//=3
a
a=5
a
# Out:
# 5

# %%
a%=2
a
# Out:
# 1

# %%
a=10
a
# Out:
# 10

# %%
a%=3
a
# Out:
# 1

# %%
a=10
a//=3
a
# Out:
# 3

# %%
a=10
b=15
print(a>b)
# Out:
# False

# %%
a<b
# Out:
# True

# %%
print(a==b)
# Out:
# True

# %%
a=10
b=15
print(a==b)
# Out:
# False

# %%
a=10
b=10
print(a<=b)
# Out:
# True

# %%
print(a>=b)
# Out:
# True

# %%
a=10
b=15
print(a<=b)
# Out:
# True

# %%
print(a>=b)
# Out:
# False
