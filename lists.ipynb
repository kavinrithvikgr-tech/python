# %%
mylist=[123,"hey","hi","orange",13,5,6,"apple","banana"]
mylist[2]=3
mylist.pop(-1)
list1=[12,"welcome",25,"kavin"]
mylist.extend(list1)
mylist.append("machan")
mylist.pop(3)
mylist
# Out:
# [123, 'hey', 3, 13, 5, 6, 'apple', 12, 'welcome', 25, 'kavin', 'machan']
