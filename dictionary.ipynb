# %%
mydict= {"brand":"hyundai", "model":"elentra", "year":"2020"}
mydict
# Out:
# {'brand': 'hyundai', 'model': 'elentra', 'year': '2020'}

# %%
mydict["brand"]
# Out:
# 'hyundai'

# %%
mydict["brand"]= "BMW"

# %%
mydict
# Out:
# {'brand': 'BMW', 'model': 'elentra', 'year': '2020'}

# %%
len(mydict)
# Out:
# 3

# %%
type(mydict)
# Out:
# dict

# %%
mydict.values()
# Out:
# dict_values(['BMW', 'elentra', '2020'])

# %%
mydict.keys()
# Out:
# dict_keys(['brand', 'model', 'year'])

# %%
mydict["plate number"] = "TN59BA2371"

# %%
mydict
# Out:
# {'brand': 'BMW',
#  'model': 'elentra',
#  'year': '2020',
#  'plate number': 'TN59BA2371'}

# %%
print(mydict)
# Out:
# {'brand': 'BMW', 'model': 'elentra', 'year': '2020', 'plate number': 'TN59BA2371'}

# %%
mydict
# Out:
# {'brand': 'BMW',
#  'model': 'elentra',
#  'year': '2020',
#  'plate number': 'TN59BA2371'}

# %%
mydict["owner name" , "country"] = "kavin", "India"
mydict
# Out:
# {'brand': 'BMW',
#  'model': 'elentra',
#  'year': '2020',
#  'plate number': 'TN59BA2371',
#  ('owner name', 'country'): ('kavin', 'India')}

# %%
k= ["owners":2]
mydict.update(k)
# Out:
#   Cell In[21], line 1
#     k= ["owners":2]
#                 ^
# SyntaxError: invalid syntax

# %%
mydict.pop("owner name")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 mydict.pop("owner name")
#
# KeyError: 'owner name'

# %%
mydict
# Out:
# {'brand': 'BMW',
#  'model': 'elentra',
#  'year': '2020',
#  'plate number': 'TN59BA2371',
#  ('owner name', 'country'): ('kavin', 'India')}

# %%
mydict.pop("brand")
# Out:
# 'BMW'

# %%
mydict
# Out:
# {'model': 'elentra',
#  'year': '2020',
#  'plate number': 'TN59BA2371',
#  ('owner name', 'country'): ('kavin', 'India')}

# %%
mydict.popitem()
# Out:
# (('owner name', 'country'), ('kavin', 'India'))

# %%
mydict
# Out:
# {'model': 'elentra', 'year': '2020', 'plate number': 'TN59BA2371'}

# %%
mydict["make"] = "BMW"

# %%
mydict
# Out:
# {'model': 'elentra',
#  'year': '2020',
#  'plate number': 'TN59BA2371',
#  'make': 'BMW'}

# %%
del mydict["year"]

# %%
mydict
# Out:
# {'model': 'elentra', 'plate number': 'TN59BA2371', 'make': 'BMW'}

# %%
mydict.clear()

# %%
mydict
# Out:
# {}

# %%
del mydict

# %%
mydict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 mydict
#
# NameError: name 'mydict' is not defined

# %%
mydict= {"brand":"hyundai", "model":"elentra", "year":"2020"}
mydict
# Out:
# {'brand': 'hyundai', 'model': 'elentra', 'year': '2020'}

# %%
myfamily={
    "child1" : {"name": "a", "year":2004},
    "child2" : {"name": "b", "year":2006},
    "child3" : {"name": "C", "year":2010}
}
myfamily
# Out:
# {'child1': {'name': 'a', 'year': 2004},
#  'child2': {'name': 'b', 'year': 2006},
#  'child3': {'name': 'C', 'year': 2010}}

# %% [markdown]
# myfamily["child1"]["name"]

# %%
myfamily["child1"]["name"]
# Out:
# 'a'

# %%
myfamily["name"]["child1"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 myfamily["name"]["child1"]
#
# KeyError: 'name'

# %%
myfamily["child1"]
# Out:
# {'name': 'a', 'year': 2004}

# %%
myfamily.values()
# Out:
# dict_values([{'name': 'a', 'year': 2004}, {'name': 'b', 'year': 2006}, {'name': 'C', 'year': 2010}])

# %%
myfamily["child1"]["name"]="kavin"

# %%
myfamily
# Out:
# {'child1': {'name': 'kavin', 'year': 2004},
#  'child2': {'name': 'b', 'year': 2006},
#  'child3': {'name': 'C', 'year': 2010}}

# %%
for i in child1.values():
    print(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 for i in "child1".values():
#       2     print(i)
#
# AttributeError: 'str' object has no attribute 'values'

# %%
for i in child1.items():
    print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 for i in child1.items():
#       2     print(i)
#
# NameError: name 'child1' is not defined

# %%
myfamily.values()
# Out:
# dict_values([{'name': 'kavin', 'year': 2004}, {'name': 'b', 'year': 2006}, {'name': 'C', 'year': 2010}])
