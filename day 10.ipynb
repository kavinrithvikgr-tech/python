# %%
mydict={
    "name" : "kavin",
    "year" : 2004,
}
print(mydict)
# Out:
# {'name': 'kavin', 'year': 2004}

# %%
mydict.get("kaaa")

# %%
mydict.keys()
# Out:
# dict_keys(['name', 'year'])

# %%
mydict.values()
# Out:
# dict_values(['kavin', 2004])

# %%
mydict.popitem()
mydict
# Out:
# {}

# %%
mydict={
    "name" : "kavin",
    "year" : 2004,
}
del mydict["name"]
mydict
# Out:
# {'year': 2004}
