# %%
try:
    a=10
    b="5"
    print(a/b)
except ZeroDivisionError:
    
    print("fahhh")
except Valueerror:
    print("aashin ore muttal")
finally:
    print("naveen ore muttal")
# Out:
# naveen ore muttal
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 4
#       3     b="5"
# ----> 4     print(a/b)
#       5 except ZeroDivisionError:
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 8
#       5 except ZeroDivisionError:
#       7     print("fahhh")
# ----> 8 except Valueerror:
#       9     print("aashin ore muttal")
#      10 finally:
#
# NameError: name 'Valueerror' is not defined

# %%
a=10
for i in range(a):
    a = [i]
    if a + b == n:
        if i == 0:
            print(f"({a}+{b})", end="")
        else:
            print(f",({a}+{b})", end="")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 4
#       2 for i in range(a):
#       3     a = [i]
# ----> 4     if a + b == n:
#       5         if i == 0:
#       6             print(f"({a}+{b})", end="")
#
# TypeError: can only concatenate list (not "int") to list

# %%
n = 10

for i in range(1, n):
    print(i, "+", n - i)
# Out:
# 1 + 9
# 2 + 8
# 3 + 7
# 4 + 6
# 5 + 5
# 6 + 4
# 7 + 3
# 8 + 2
# 9 + 1
